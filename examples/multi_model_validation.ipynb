# %% [markdown]
# # Predictive validity tutorial #2

# %% [markdown]
# ### Sparse data set containing multiple endpoints

# %%
import os
import pandas as pd
from mosses.predictive_validity import evaluate_pv

# %% [markdown]
# The arguments required by `evaluate_pv()` can be passed as a dictionary of keyword arguments.\
# Here we show that the arguments can be build directly in Jupyter.\
# As part of preparing the arguments, `input_df` is used to load the corresponding dataframe needed by the function.

# %%
# Load dataframe from path
data_dir = os.path.join("data")
config_dict = dict()
data = pd.read_csv(os.path.join(data_dir, "multi_objective_validation_1.csv"))

# %% [markdown]
# Arguments here are generated by a factory which

# %%
from copy import deepcopy

# Configure the dictionary template and the models in the data set
models = ("logd", "hlm_clint", "herg", "rh_clint", "solubility", "caco2_efflux_ratio")

dict_template = {
    "input_df": data,
    "observed_column": "{model_name}_exp",
    "predicted_column": "{model_name}_pred",
    "model_version": "{model_name}_model_version",
    "training_set_column": "{model_name}_set_split",
    "plot_title": "{model_name}",
    "sample_registration_date": "cpd_reg_date",
    
    # User-defined parameters
    "pos_class": "<=",
    "current_threshold": 3,
    "plot_scale": "linear"
}

class ModelDictFactory:
    def make_config_dict(model_name):
        config_dict = deepcopy(dict_template)
        for k, v in config_dict.items():
            config_dict[k] = v.format(model_name=model_name) if isinstance(v, str) else v
        return config_dict

# %%
import matplotlib.pyplot as plt
from matplotlib.backends.backend_pdf import PdfPages

def capture_plots_to_pdf(func, filename, *args, **kwargs):
    captured_figures = []
    original_figure = plt.figure
    original_subplots = plt.subplots

    def wrapped_figure(*f_args, **f_kwargs):
        fig = original_figure(*f_args, **f_kwargs)
        captured_figures.append(fig)
        return fig

    def wrapped_subplots(*f_args, **f_kwargs):
        fig, ax = original_subplots(*f_args, **f_kwargs)
        captured_figures.append(fig)
        return fig, ax

    plt.figure = wrapped_figure
    plt.subplots = wrapped_subplots

    try:
        func(*args, **kwargs)
    finally:
        # Restore the original functions
        plt.figure = original_figure
        plt.subplots = original_subplots

    # Save captured figures
    with PdfPages(filename) as pdf:
        for fig in captured_figures:
            pdf.savefig(fig)
            plt.close(fig)

# %%
# Capture all images into a PDF
def evaluate_pv_batch():
    for model_name in models:
        config_dict = ModelDictFactory.make_config_dict(model_name)
        evaluate_pv(**config_dict)

capture_plots_to_pdf(evaluate_pv_batch, "multi_model_validation_plots.pdf")
# Out:
# ### Overview
# ---
# |  | No. of Compounds |
# | ------ | ----- |
# | Compounds with measured values | 920 |
# | Below Selected Experimental Threshold | 831 |
# | Above Selected Experimental Threshold | 89 |
# | Ratio of good compounds made so far | 9% |
# | Prospective Validation Set | 723 |
# ---
# ### Experimental values over time
# ---
# ### Model evaluation
# #### Predicted vs Experimental Values (prospective)
# | Metric | Value |
# | ------ | ----- |
# | Experimental vs Predicted correlation (Coefficient of determination, R²) | 0.8 |
# | Root Mean Squared Error (RMSE in log scale) | 0.55 |
# #### Model performance over time
# ##### RMSE
# ##### Similarity of prospective data to training set
# ---
# ### Model usage advice
# #### What predicted threshold gives best enrichment
# |  | Predicted Threshold | PPV % | FOR % |
# | ------ | ----- | ----- | ----- |
# | Selected Experimental Threshold | 3 | 97 | 7 |
# | Recommended Threshold | 3.0 | 97 | 7 |
# #### Explore other experimental thresholds
# | Experimental = Predicted threshold | PPV % | FOR % |
# | ----- | ----- | ----- |
# | 2.9 | 96 | 4 |
# ### Overview
# ---
# |  | No. of Compounds |
# | ------ | ----- |
# | Compounds with measured values | 920 |
# | Below Selected Experimental Threshold | 409 |
# | Above Selected Experimental Threshold | 511 |
# | Ratio of good compounds made so far | 55% |
# | Prospective Validation Set | 732 |
# ---
# ### Experimental values over time
# ---
# ### Model evaluation
# #### Predicted vs Experimental Values (prospective)
# | Metric | Value |
# | ------ | ----- |
# | Experimental vs Predicted correlation (Coefficient of determination, R²) | 0.1 |
# | Root Mean Squared Error (RMSE in log scale) | 46.19 |
# #### Model performance over time
# ##### RMSE
# ##### Similarity of prospective data to training set
# ---
# ### Model usage advice
# #### What predicted threshold gives best enrichment
# |  | Predicted Threshold | PPV % | FOR % |
# | ------ | ----- | ----- | ----- |
# | Selected Experimental Threshold | 3 | 82 | 45 |
# | Recommended Threshold | 40.0 | 51 | 3 |
# #### Explore other experimental thresholds
# | Experimental = Predicted threshold | PPV % | FOR % |
# | ----- | ----- | ----- |
# | 40.0 | 91 | 37 |
# ### Overview
# ---
# |  | No. of Compounds |
# | ------ | ----- |
# | Compounds with measured values | 292 |
# | Below Selected Experimental Threshold | 0 |
# | Above Selected Experimental Threshold | 292 |
# | Ratio of good compounds made so far | 100% |
# | Prospective Validation Set | 120 |
# ---
# ### Experimental values over time
# ---
# ### Model evaluation
# #### Predicted vs Experimental Values (prospective)
# | Metric | Value |
# | ------ | ----- |
# | Experimental vs Predicted correlation (Coefficient of determination, R²) | 0.0 |
# | Root Mean Squared Error (RMSE in log scale) | 0.55 |
# #### Model performance over time
# ##### RMSE
# ##### Similarity of prospective data to training set
# ---
# ### Model usage advice
# #### What predicted threshold gives best enrichment
# |  | Predicted Threshold | PPV % | FOR % |
# | ------ | ----- | ----- | ----- |
# | Selected Experimental Threshold | 3 | 0 | 0 |
# | Recommended Threshold | 5.4 | 0 | 0 |
# #### Explore other experimental thresholds
# | Experimental = Predicted threshold | PPV % | FOR % |
# | ----- | ----- | ----- |
# | 4.4 | 100 | 83 |
# ### Overview
# ---
# |  | No. of Compounds |
# | ------ | ----- |
# | Compounds with measured values | 893 |
# | Below Selected Experimental Threshold | 186 |
# | Above Selected Experimental Threshold | 707 |
# | Ratio of good compounds made so far | 79% |
# | Prospective Validation Set | 649 |
# ---
# ### Experimental values over time
# ---
# ### Model evaluation
# #### Predicted vs Experimental Values (prospective)
# | Metric | Value |
# | ------ | ----- |
# | Experimental vs Predicted correlation (Coefficient of determination, R²) | 0.3 |
# | Root Mean Squared Error (RMSE in log scale) | 39.82 |
# #### Model performance over time
# ##### RMSE
# ##### Similarity of prospective data to training set
# ---
# ### Model usage advice
# #### What predicted threshold gives best enrichment
# |  | Predicted Threshold | PPV % | FOR % |
# | ------ | ----- | ----- | ----- |
# | Selected Experimental Threshold | 3 | 72 | 21 |
# | Recommended Threshold | 4.2 | 71 | 18 |
# #### Explore other experimental thresholds
# | Experimental = Predicted threshold | PPV % | FOR % |
# | ----- | ----- | ----- |
# | 59.0 | 91 | 27 |
# ### Overview
# ---
# |  | No. of Compounds |
# | ------ | ----- |
# | Compounds with measured values | 928 |
# | Below Selected Experimental Threshold | 56 |
# | Above Selected Experimental Threshold | 872 |
# | Ratio of good compounds made so far | 93% |
# | Prospective Validation Set | 591 |
# ---
# ### Experimental values over time
# ---
# ### Model evaluation
# #### Predicted vs Experimental Values (prospective)
# | Metric | Value |
# | ------ | ----- |
# | Experimental vs Predicted correlation (Coefficient of determination, R²) | 0.0 |
# | Root Mean Squared Error (RMSE in log scale) | 998.58 |
# #### Model performance over time
# ##### RMSE
# ##### Similarity of prospective data to training set
# ---
# ### Model usage advice
# #### What predicted threshold gives best enrichment
# |  | Predicted Threshold | PPV % | FOR % |
# | ------ | ----- | ----- | ----- |
# | Selected Experimental Threshold | 3 | 0 | 4 |
# | Recommended Threshold | 2166.5 | 5 | 0 |
# #### Explore other experimental thresholds
# | Experimental = Predicted threshold | PPV % | FOR % |
# | ----- | ----- | ----- |
# | 619.2 | 43 | 13 |
# ### Overview
# ---
# |  | No. of Compounds |
# | ------ | ----- |
# | Compounds with measured values | 385 |
# | Below Selected Experimental Threshold | 122 |
# | Above Selected Experimental Threshold | 263 |
# | Ratio of good compounds made so far | 68% |
# | Prospective Validation Set | 381 |
# ---
# ### Experimental values over time
# ---
# ### Model evaluation
# #### Predicted vs Experimental Values (prospective)
# | Metric | Value |
# | ------ | ----- |
# | Experimental vs Predicted correlation (Coefficient of determination, R²) | 0.4 |
# | Root Mean Squared Error (RMSE in log scale) | 46.96 |
# #### Model performance over time
# ##### RMSE
# ##### Similarity of prospective data to training set
# ---
# ### Model usage advice
# #### What predicted threshold gives best enrichment
# |  | Predicted Threshold | PPV % | FOR % |
# | ------ | ----- | ----- | ----- |
# | Selected Experimental Threshold | 3 | 96 | 23 |
# | Recommended Threshold | 3.0 | 96 | 22 |
# #### Explore other experimental thresholds
# | Experimental = Predicted threshold | PPV % | FOR % |
# | ----- | ----- | ----- |
# | 3.0 | 95 | 23 |
