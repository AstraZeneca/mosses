# %% [markdown]
# # Heatmap tutorial

# %%
import os
import json
import pandas as pd
import warnings
from mosses.heatmap import project_heatmap_stats

# Ignoring some warnings to avoid cluttering the screen
warnings.simplefilter(action='ignore', category=FutureWarning)
warnings.simplefilter(action='ignore', category=pd.errors.SettingWithCopyWarning)
warnings.simplefilter(action='ignore', category=UserWarning)

# %%
# Load data from file
data_dir = os.path.join("data")
data = pd.read_csv(os.path.join(data_dir, "multi_objective_validation_1.csv"))

# Load model config from file
with open(os.path.join(data_dir, "heatmap_model_configuration.json")) as f:
    config_dict = json.load(f)

# %% [markdown]
# In this case, the data was loaded in CSV as shown for the Predictive Validity tutorial, whilst the model config is passed as a JSON file. That could be converted into a YAML file similar to that used before, if preferable.
#
# Note that as an example, only some models among those present in the data are configured to be processed by the heatmap. If more model configurations are added to the JSON file, more entries will be included in the heatmap.

# %%
project_heatmap_stats(
    df=data,
    models_metadata=config_dict,
    series_column='series',
)
# Out:
# <style type="text/css">
# #T_c29c8 thead th {
#   text-align: left;
# }
# #T_c29c8_row0_col0, #T_c29c8_row0_col1, #T_c29c8_row0_col2, #T_c29c8_row0_col3, #T_c29c8_row0_col4, #T_c29c8_row0_col5, #T_c29c8_row0_col6, #T_c29c8_row0_col7, #T_c29c8_row0_col8, #T_c29c8_row0_col9, #T_c29c8_row0_col10, #T_c29c8_row0_col11, #T_c29c8_row0_col12, #T_c29c8_row0_col14, #T_c29c8_row0_col15, #T_c29c8_row0_col16, #T_c29c8_row1_col0, #T_c29c8_row1_col1, #T_c29c8_row1_col2, #T_c29c8_row1_col3, #T_c29c8_row1_col4, #T_c29c8_row1_col5, #T_c29c8_row1_col6, #T_c29c8_row1_col7, #T_c29c8_row1_col8, #T_c29c8_row1_col9, #T_c29c8_row1_col10, #T_c29c8_row1_col11, #T_c29c8_row1_col12, #T_c29c8_row1_col14, #T_c29c8_row1_col15, #T_c29c8_row1_col16, #T_c29c8_row2_col0, #T_c29c8_row2_col1, #T_c29c8_row2_col2, #T_c29c8_row2_col3, #T_c29c8_row2_col4, #T_c29c8_row2_col5, #T_c29c8_row2_col6, #T_c29c8_row2_col7, #T_c29c8_row2_col8, #T_c29c8_row2_col9, #T_c29c8_row2_col10, #T_c29c8_row2_col11, #T_c29c8_row2_col12, #T_c29c8_row2_col14, #T_c29c8_row2_col15, #T_c29c8_row2_col16, #T_c29c8_row3_col0, #T_c29c8_row3_col1, #T_c29c8_row3_col2, #T_c29c8_row3_col3, #T_c29c8_row3_col4, #T_c29c8_row3_col5, #T_c29c8_row3_col6, #T_c29c8_row3_col7, #T_c29c8_row3_col8, #T_c29c8_row3_col9, #T_c29c8_row3_col10, #T_c29c8_row3_col11, #T_c29c8_row3_col12, #T_c29c8_row3_col14, #T_c29c8_row3_col15, #T_c29c8_row3_col16, #T_c29c8_row4_col0, #T_c29c8_row4_col1, #T_c29c8_row4_col2, #T_c29c8_row4_col3, #T_c29c8_row4_col4, #T_c29c8_row4_col5, #T_c29c8_row4_col6, #T_c29c8_row4_col7, #T_c29c8_row4_col8, #T_c29c8_row4_col9, #T_c29c8_row4_col10, #T_c29c8_row4_col11, #T_c29c8_row4_col12, #T_c29c8_row4_col14, #T_c29c8_row4_col15, #T_c29c8_row4_col16, #T_c29c8_row5_col0, #T_c29c8_row5_col1, #T_c29c8_row5_col2, #T_c29c8_row5_col3, #T_c29c8_row5_col4, #T_c29c8_row5_col5, #T_c29c8_row5_col6, #T_c29c8_row5_col7, #T_c29c8_row5_col8, #T_c29c8_row5_col9, #T_c29c8_row5_col10, #T_c29c8_row5_col11, #T_c29c8_row5_col12, #T_c29c8_row5_col14, #T_c29c8_row5_col15, #T_c29c8_row5_col16, #T_c29c8_row6_col0, #T_c29c8_row6_col1, #T_c29c8_row6_col2, #T_c29c8_row6_col3, #T_c29c8_row6_col4, #T_c29c8_row6_col5, #T_c29c8_row6_col6, #T_c29c8_row6_col7, #T_c29c8_row6_col8, #T_c29c8_row6_col9, #T_c29c8_row6_col10, #T_c29c8_row6_col11, #T_c29c8_row6_col12, #T_c29c8_row6_col14, #T_c29c8_row6_col15, #T_c29c8_row6_col16, #T_c29c8_row7_col0, #T_c29c8_row7_col1, #T_c29c8_row7_col2, #T_c29c8_row7_col3, #T_c29c8_row7_col4, #T_c29c8_row7_col5, #T_c29c8_row7_col6, #T_c29c8_row7_col7, #T_c29c8_row7_col8, #T_c29c8_row7_col9, #T_c29c8_row7_col10, #T_c29c8_row7_col11, #T_c29c8_row7_col12, #T_c29c8_row7_col14, #T_c29c8_row7_col15, #T_c29c8_row7_col16, #T_c29c8_row8_col0, #T_c29c8_row8_col1, #T_c29c8_row8_col2, #T_c29c8_row8_col3, #T_c29c8_row8_col4, #T_c29c8_row8_col5, #T_c29c8_row8_col6, #T_c29c8_row8_col7, #T_c29c8_row8_col8, #T_c29c8_row8_col9, #T_c29c8_row8_col10, #T_c29c8_row8_col11, #T_c29c8_row8_col12, #T_c29c8_row8_col14, #T_c29c8_row8_col15, #T_c29c8_row8_col16 {
#   text-align: left;
# }
# #T_c29c8_row0_col13, #T_c29c8_row4_col18 {
#   background-color: grey;
#   text-align: left;
# }
# #T_c29c8_row0_col17, #T_c29c8_row2_col13 {
#   background-color: red;
#   text-align: left;
# }
# #T_c29c8_row0_col18, #T_c29c8_row1_col13, #T_c29c8_row1_col17, #T_c29c8_row1_col18, #T_c29c8_row2_col18, #T_c29c8_row3_col13, #T_c29c8_row3_col17, #T_c29c8_row3_col18, #T_c29c8_row4_col13, #T_c29c8_row4_col17, #T_c29c8_row5_col18, #T_c29c8_row6_col13, #T_c29c8_row6_col17, #T_c29c8_row6_col18, #T_c29c8_row7_col13, #T_c29c8_row7_col17, #T_c29c8_row7_col18, #T_c29c8_row8_col18 {
#   background-color: green;
#   text-align: left;
# }
# #T_c29c8_row2_col17, #T_c29c8_row5_col13, #T_c29c8_row5_col17, #T_c29c8_row8_col13, #T_c29c8_row8_col17 {
#   background-color: orange;
#   text-align: left;
# }
# </style>
# <table id="T_c29c8">
#   <thead>
#     <tr>
#       <th id="T_c29c8_level0_col0" class="col_heading level0 col0" >Model</th>
#       <th id="T_c29c8_level0_col1" class="col_heading level0 col1" >Category</th>
#       <th id="T_c29c8_level0_col2" class="col_heading level0 col2" >Series</th>
#       <th id="T_c29c8_level0_col3" class="col_heading level0 col3" >Aim</th>
#       <th id="T_c29c8_level0_col4" class="col_heading level0 col4" >SET</th>
#       <th id="T_c29c8_level0_col5" class="col_heading level0 col5" >Units</th>
#       <th id="T_c29c8_level0_col6" class="col_heading level0 col6" >Compounds with measured values</th>
#       <th id="T_c29c8_level0_col7" class="col_heading level0 col7" >Compounds Obeying SET %</th>
#       <th id="T_c29c8_level0_col8" class="col_heading level0 col8" >Exp_Error (log)</th>
#       <th id="T_c29c8_level0_col9" class="col_heading level0 col9" >RMSE (log)</th>
#       <th id="T_c29c8_level0_col10" class="col_heading level0 col10" >R2</th>
#       <th id="T_c29c8_level0_col11" class="col_heading level0 col11" >PPV %</th>
#       <th id="T_c29c8_level0_col12" class="col_heading level0 col12" >FOR %</th>
#       <th id="T_c29c8_level0_col13" class="col_heading level0 col13" >Model Quality</th>
#       <th id="T_c29c8_level0_col14" class="col_heading level0 col14" >Opt Pred Threshold</th>
#       <th id="T_c29c8_level0_col15" class="col_heading level0 col15" >PPVopt %</th>
#       <th id="T_c29c8_level0_col16" class="col_heading level0 col16" >FORopt %</th>
#       <th id="T_c29c8_level0_col17" class="col_heading level0 col17" >Model Quality opt</th>
#       <th id="T_c29c8_level0_col18" class="col_heading level0 col18" >Time Dependant Stability Class</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_c29c8_row0_col0" class="data row0 col0" >logD</td>
#       <td id="T_c29c8_row0_col1" class="data row0 col1" >PhysChem</td>
#       <td id="T_c29c8_row0_col2" class="data row0 col2" >anion</td>
#       <td id="T_c29c8_row0_col3" class="data row0 col3" >below</td>
#       <td id="T_c29c8_row0_col4" class="data row0 col4" >3.0</td>
#       <td id="T_c29c8_row0_col5" class="data row0 col5" ></td>
#       <td id="T_c29c8_row0_col6" class="data row0 col6" >337</td>
#       <td id="T_c29c8_row0_col7" class="data row0 col7" >91</td>
#       <td id="T_c29c8_row0_col8" class="data row0 col8" >0.1</td>
#       <td id="T_c29c8_row0_col9" class="data row0 col9" >0.5</td>
#       <td id="T_c29c8_row0_col10" class="data row0 col10" >0.7</td>
#       <td id="T_c29c8_row0_col11" class="data row0 col11" >100</td>
#       <td id="T_c29c8_row0_col12" class="data row0 col12" ></td>
#       <td id="T_c29c8_row0_col13" class="data row0 col13" >NA in area of SET</td>
#       <td id="T_c29c8_row0_col14" class="data row0 col14" >2.2</td>
#       <td id="T_c29c8_row0_col15" class="data row0 col15" >100</td>
#       <td id="T_c29c8_row0_col16" class="data row0 col16" >93</td>
#       <td id="T_c29c8_row0_col17" class="data row0 col17" >Bad</td>
#       <td id="T_c29c8_row0_col18" class="data row0 col18" >Stable</td>
#     </tr>
#     <tr>
#       <td id="T_c29c8_row1_col0" class="data row1 col0" >Caco2 Efflux ratio</td>
#       <td id="T_c29c8_row1_col1" class="data row1 col1" >Permeability</td>
#       <td id="T_c29c8_row1_col2" class="data row1 col2" >anion</td>
#       <td id="T_c29c8_row1_col3" class="data row1 col3" >below</td>
#       <td id="T_c29c8_row1_col4" class="data row1 col4" >10.0</td>
#       <td id="T_c29c8_row1_col5" class="data row1 col5" ></td>
#       <td id="T_c29c8_row1_col6" class="data row1 col6" >108</td>
#       <td id="T_c29c8_row1_col7" class="data row1 col7" >50</td>
#       <td id="T_c29c8_row1_col8" class="data row1 col8" >0.1</td>
#       <td id="T_c29c8_row1_col9" class="data row1 col9" >0.3</td>
#       <td id="T_c29c8_row1_col10" class="data row1 col10" >0.7</td>
#       <td id="T_c29c8_row1_col11" class="data row1 col11" >84</td>
#       <td id="T_c29c8_row1_col12" class="data row1 col12" >27</td>
#       <td id="T_c29c8_row1_col13" class="data row1 col13" >Good</td>
#       <td id="T_c29c8_row1_col14" class="data row1 col14" >6.2</td>
#       <td id="T_c29c8_row1_col15" class="data row1 col15" >97</td>
#       <td id="T_c29c8_row1_col16" class="data row1 col16" >29</td>
#       <td id="T_c
